# %% [markdown]
# ### Фильтрация картинок при помощи pytorch torch.nn.Conv2d

# %%
import torch
import torch.nn as nn
import torchvision
from PIL import Image
from torchvision import transforms

# %%
filename = 'image.png'
image = Image.open(filename)
image = image.convert('RGB')
image
# Out:
# <PIL.Image.Image image mode=RGB size=285x162>

# %%
conv_model = nn.Conv2d( in_channels=3, 
                        out_channels=3, 
                        kernel_size=3, 
                        padding=2, 
                        stride=1, 
                        bias=False, 
                        groups=3
                        )
print('Исходные случайные веса в слое:')
print(conv_model.weight.shape)
print(conv_model.weight)
# Out:
# Исходные случайные веса в слое:
# torch.Size([3, 1, 3, 3])
# Parameter containing:
# tensor([[[[-2.9794e-01, -4.5954e-02,  2.9075e-01],
#           [ 6.2409e-02, -3.2295e-01, -1.1171e-01],
#           [ 1.2022e-01, -2.0706e-01,  3.1161e-01]]],
#
#
#         [[[-2.9549e-01,  1.5240e-01,  1.2497e-01],
#           [ 2.8796e-01,  1.5119e-01, -1.7388e-01],
#           [ 6.2944e-02,  2.9474e-01,  1.6140e-01]]],
#
#
#         [[[ 2.9076e-02, -2.2512e-01,  1.1019e-03],
#           [-3.1525e-01,  2.0081e-01, -1.9813e-04],
#           [-1.7575e-01, -4.6111e-02, -1.0985e-01]]]], requires_grad=True)

# %%
sobel_x =   [[-1,-2,-1],[0,0,0],[1,2,1]]
sobel_y =   [[-1,0,1],[-2,0,2],[-1,0,1]]
edges =     [[-1,-1,-1],[-1,8,-1],[-1,-1,-1]]
unsharp =   [[-1,-4,-1],[-4,26,-4],[-1,-4,-1]]
blur =      [[1,1,1],[1,1,1],[1,1,1]]
gauss =     [[1,2,1],[2,4,2],[1,2,1]]
nochange =  [[0,0,0],[0,1,0],[0,0,0]]


W = torch.tensor(sobel_x)   #фильтр

with torch.no_grad():
    conv_model.weight.copy_(W)

print('Новые веса в слое:')
print(conv_model.weight.shape)
print(conv_model.weight)
# Out:
# Новые веса в слое:
# torch.Size([3, 1, 3, 3])
# Parameter containing:
# tensor([[[[-1., -2., -1.],
#           [ 0.,  0.,  0.],
#           [ 1.,  2.,  1.]]],
#
#
#         [[[-1., -2., -1.],
#           [ 0.,  0.,  0.],
#           [ 1.,  2.,  1.]]],
#
#
#         [[[-1., -2., -1.],
#           [ 0.,  0.,  0.],
#           [ 1.,  2.,  1.]]]], requires_grad=True)

# %%
t1 = transforms.ToTensor()
tensor_image = t1(image)
tensor_image.shape
# Out:
# torch.Size([3, 162, 285])

# %%
tensor_image = tensor_image.unsqueeze(dim=0)
tensor_image.shape
# Out:
# torch.Size([1, 3, 162, 285])

# %%
result = conv_model(tensor_image)

# %%
result.shape
# Out:
# torch.Size([1, 3, 164, 287])

# %%
result = result.squeeze(dim=0)
print(result.shape)
# Out:
# torch.Size([3, 164, 287])

# %%
t_image = result + 1
t_image = t_image - t_image.min()
t_image_normalized = t_image / (t_image.max() - t_image.min())

# %%
print(t_image_normalized.min())
print(t_image_normalized.max())
# Out:
# tensor(0., grad_fn=<MinBackward1>)
# tensor(1., grad_fn=<MaxBackward1>)

# %%
t2 = transforms.ToPILImage()
new_image = t2(t_image_normalized)
new_image
# Out:
# <PIL.Image.Image image mode=RGB size=287x164>
